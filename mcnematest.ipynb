# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
dir = '/content/drive/MyDrive/VU-thesis-2023/'

# %%
# %%capture

# !pip install mlxtend

# %%
from mlxtend.evaluate import mcnemar
from mlxtend.evaluate import mcnemar_table
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix,  ConfusionMatrixDisplay
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### McNemar test

# %%
def mcnemartest(y_target, y_model1, y_model2, alpha):

    tb = mcnemar_table(y_target=y_target,
                   y_model1=y_model1,
                   y_model2=y_model2)
    # print(tb)
    chi2, p = mcnemar(ary=tb, corrected=False)
    print('chi-squared:', chi2)
    print('p-value:', p)
    if p > alpha:
      print('not signifcant (failed to reject H0)')
    else:
      print('significant (reject H0)')

# %% [markdown]
# ### Confusion matrix

# %%
def cm_plot(gold, pred, title):
  cm=confusion_matrix(gold, pred)
  plt.rcParams['font.size'] = 16
  disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['0', '1', '2'])
  disp.plot(cmap='Blues')
  disp.ax_.set_title(title)
  plt.show()

# %% [markdown]
# ### Co-occurrence matrix

# %%
co_mat = pd.crosstab(pred1, pred2)
co_mat
